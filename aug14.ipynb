# %% [markdown]
# # section A - Variavles,Data types and built in Functions

# %%
name = "Nayan"
age = 22
percentage = 73.89
placed = True 

print (name, "Data type =", type(name))
print (age, "Data type =", type(age))
print (percentage, "Data type =", type(percentage))
print (placed, "Data type =", type(placed))
# Out:
# Nayan Data type = <class 'str'>
# 22 Data type = <class 'int'>
# 73.89 Data type = <class 'float'>
# True Data type = <class 'bool'>

# %%
age = input("Enter your age:")
print ("your age after 5 years will be:",int(age) + 5)
# Out:
# your age after 5 years will be: 27

# %%
values = [25,40,18,67,32]
print(min(values))
print(max(values))
print(sum(values))
# Out:
# 18
# 67
# 182

# %%
amount = 1000
marks = 75.5
complex = 2 + 3j
print (amount,type(amount))
print (marks,type(marks))
print (complex,type(complex))
# Out:
# 1000 <class 'int'>
# 75.5 <class 'float'>
# (2+3j) <class 'complex'>

# %%
name = "Nayan Dokhale"
print (len(name))
# Out:
# 13

# %%
var1 = 78.4567
print (round(var1))
# Out:
# 78

# %%
num = input("Enter your number ")
print (pow(int(num),2))
print (pow(int(num),3))
# Out:
# 4
# 8

# %% [markdown]
# # Section B : Operators

# %%
num1 = int(input("Enter first  number"))
num2 = int(input("Enter second number"))
print ("Addition = ",(num1) + (num2))
print ("Multiplicationn = ",(num1) * (num2))
print ("Substraction = ",(num1) - (num2))
print ("Division = ",(num1) / (num2))
print ("MOdulus = ",(num1) % (num2))
print ("floor Division = ",(num1) // (num2))
print ("Exponentiation = ",(num1) ** (num2))
# Out:
# Addition =  7
# Multiplicationn =  12
# Substraction =  1
# Division =  1.3333333333333333
# MOdulus =  1
# floor Division =  1
# Exponentiation =  64

# %%
age = int(input("Enter your age:"))
percentage = float(input("Enter your percentage:"))
if (age >= 18) and (percentage >= 60):
    print("true")
else:
    print("false")
# Out:
# true

# %%
x = 100
x += 20
print(x)

x -= 10
print(x)

x *= 2
print(x)

x /= 5
print(x)
# Out:
# 120
# 110
# 220
# 44.0

# %%
marks = int(input("Enter your marks:"))
if marks >= 60 :
    print("You are eligible ")
else:
    print ("You are not eligible")
# Out:
# You are not eligible

# %%
num = int(input("Enter your number:"))
if num % 2 == 0:
    print ("number is even")
else:
    print ("number is odd")
# Out:
# number is even

# %% [markdown]
# # Section C - String Basics

# %%
s = "KiranAcademy"
print ( len(s),s[0],s[4],s[-1])
# Out:
# 12 K n y

# %%
s =  "Programming"
print(s[0:5])
print(s[-4:-1])
print(s[-1:-12:-1])
# Out:
# Progr
# min
# gnimmargorP

# %%
s = " python full stack "
print(s.strip())
print(s.upper())
print(s.lower())
print(s.title())
print(s.replace("python","Java"))
# Out:
# python full stack
#  PYTHON FULL STACK
#  python full stack
#  Python Full Stack
#  Java full stack

# %%
s = "Java Python testing data"
print("Python" in s)
print(s.find("testing"))
# Out:
# True
# 12

# %%
s = "banana"
print (s.count("a"))
print (s.count("n"))
# Out:
# 3
# 2

# %%
s =  "Kiran Academy Pune"
print (s.startswith("Kiran"))
print (s.endswith("Pune"))
# Out:
# True
# True

# %%
text = "Java, Python, React, SQL"
values = text.split(",")
print(values)
# Out:
# ['Java', ' Python', ' React', ' SQL']

# %%
l = ["Python", "Java", "SQL"]
result = " - ".join(l)
print(result)
# Out:
# Python - Java - SQL

# %%
text = "I am learning Java"
new_text = text.replace("Java", "Python")
print(new_text)
# Out:
# I am learning Python

# %%
word = input("Enter your word:")
if word == word.upper():
    print("word is in upper case")
elif word == word.lower():
    print("word is in lower case")
else:
    print ("word is in mixed case")
# Out:
# word is in mixed case

# %% [markdown]
# # Section D- Mini practical task

# %%
name = input("Enter your name:")
course = input("Enter your course:")
marks = float(input("Enter your marks:"))

if marks >=60:
    print( "You are eligible")
else:
    print( "You are not eligible")

print(f"student:{name}, curse:{course}, marks:{marks},status:{status}")
# Out:
# You are eligible
# student:Nayan, curse:Data Analytics, marks:88.8,status:You are eligible

# %%
product = input("Enter product name")
quantity = int(input("Enter quantity"))
price = float(input("Enter price per unit"))

total = quantity*price
print (total)

print(f"product:{product}")
print(f"quantity:{quantity}")
print(f"price per unit:{price}")
print(f"total bill:{total}")
# Out:
# 130000.0
# product:Laptop
# quantity:2
# price per unit:65000.0
# total bill:130000.0
